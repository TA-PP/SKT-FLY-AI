# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt

# %%
csv = pd.read_csv('./자료/해양쓰레기.csv', encoding='euc-kr')

# %%
csv.head(10)
# Out:
#      번호    연도        단체        지역  차수    유형  \
# 0  1604  2017  제주환경운동연합  제주 사계리해안  6차    기타
# 1  1604  2017  제주환경운동연합  제주 사계리해안  6차    기타
# 2  1604  2017  제주환경운동연합  제주 사계리해안  6차    기타
# 3  1604  2017  제주환경운동연합  제주 사계리해안  6차    기타
# 4  1604  2017  제주환경운동연합  제주 사계리해안  6차    기타
# 5  1604  2017  제주환경운동연합  제주 사계리해안  6차    기타
# 6  1604  2017  제주환경운동연합  제주 사계리해안  6차    기타
# 7  1604  2017  제주환경운동연합  제주 사계리해안  6차    기타
# 8  1604  2017  제주환경운동연합  제주 사계리해안  6차  외국기인
# 9  1604  2017  제주환경운동연합  제주 사계리해안  6차  외국기인
#
#                                                 상세유형  개수
# 0  스폰지, 건전지, 양초 등 기타 (슬레이트, 장판, 동파방지용 유리섬유조각,항아리 ... NaN
# 1                                        낚싯대, 낚시용품 등 NaN
# 2                                            도자기, 타일 NaN
# 3                                       배터리(차량용,공업용) NaN
# 4                                   건축자재(콘크리트, 벽돌 등) NaN
# 5                                                드럼통 NaN
# 6                                            차량/차량부품 NaN
# ...

# %%
jeju = csv[(csv['지역'] == '제주 사계리해안')]

jeju
# Out:
#          번호    연도        단체        지역  차수     유형  \
# 0      1604  2017  제주환경운동연합  제주 사계리해안  6차     기타
# 1      1604  2017  제주환경운동연합  제주 사계리해안  6차     기타
# 2      1604  2017  제주환경운동연합  제주 사계리해안  6차     기타
# 3      1604  2017  제주환경운동연합  제주 사계리해안  6차     기타
# 4      1604  2017  제주환경운동연합  제주 사계리해안  6차     기타
# ...     ...   ...       ...       ...  ..    ...
# 48595   896  2015  제주환경운동연합  제주 사계리해안  1차  플라스틱류
# 48596   896  2015  제주환경운동연합  제주 사계리해안  1차  플라스틱류
# 48597   896  2015  제주환경운동연합  제주 사계리해안  1차  플라스틱류
# 48598   896  2015  제주환경운동연합  제주 사계리해안  1차  플라스틱류
# 48599   896  2015  제주환경운동연합  제주 사계리해안  1차  플라스틱류
#
#                                                     상세유형    개수
# 0      스폰지, 건전지, 양초 등 기타 (슬레이트, 장판, 동파방지용 유리섬유조각,항아리 ...   NaN
# 1                                            낚싯대, 낚시용품 등   NaN
# 2                                                도자기, 타일   NaN
# 3                                           배터리(차량용,공업용)   NaN
# ...

# %%
jeju.columns
# Out:
# Index(['번호', '연도', '단체', '지역', '차수', '유형', '상세유형', '개수'], dtype='object')

# %%
jeju.isnull().sum()
# Out:
# 번호        0
# 연도        0
# 단체        0
# 지역        0
# 차수        0
# 유형        0
# 상세유형      0
# 개수      423
# dtype: int64

# %%
# null값이 423개 밖에 되지 않아서 없어도 크게 영향을 미치지 않을거라고 생각 -> 0으로 대체
jeju = jeju.fillna(0)

# %%
jeju.isnull().sum()
# Out:
# 번호      0
# 연도      0
# 단체      0
# 지역      0
# 차수      0
# 유형      0
# 상세유형    0
# 개수      0
# dtype: int64

# %%
jeju['유형'].unique()
# Out:
# array(['기타', '외국기인', '흡연 / 불꽃 놀이', '의료 및 개인위생', '고무', '유리', '의류 및 천',
#        '금속', '나무', '스티로폼', '종이', '플라스틱류'], dtype=object)

# %%
jeju2015 = jeju[jeju['연도'] == 2015]
jeju2016 = jeju[jeju['연도'] == 2016]
jeju2017 = jeju[jeju['연도'] == 2017]

# %%
jeju2015
# Out:
#          번호    연도        단체        지역  차수     유형  \
# 48000  1106  2015  제주환경운동연합  제주 사계리해안  6차     기타
# 48001  1106  2015  제주환경운동연합  제주 사계리해안  6차     기타
# 48002  1106  2015  제주환경운동연합  제주 사계리해안  6차     기타
# 48003  1106  2015  제주환경운동연합  제주 사계리해안  6차     기타
# 48004  1106  2015  제주환경운동연합  제주 사계리해안  6차     기타
# ...     ...   ...       ...       ...  ..    ...
# 48595   896  2015  제주환경운동연합  제주 사계리해안  1차  플라스틱류
# 48596   896  2015  제주환경운동연합  제주 사계리해안  1차  플라스틱류
# 48597   896  2015  제주환경운동연합  제주 사계리해안  1차  플라스틱류
# 48598   896  2015  제주환경운동연합  제주 사계리해안  1차  플라스틱류
# 48599   896  2015  제주환경운동연합  제주 사계리해안  1차  플라스틱류
#
#                                                     상세유형    개수
# 48000  스폰지, 건전지, 양초 등 기타 (슬레이트, 장판, 동파방지용 유리섬유조각,항아리 ...   2.0
# 48001                                        낚싯대, 낚시용품 등   0.0
# 48002                                            도자기, 타일   0.0
# 48003                                       배터리(차량용,공업용)   0.0
# ...

# %%
jeju2015 = jeju2015.groupby('유형').sum()
jeju2015.loc[:, ['개수']]

plt.rc('font', family='Malgun Gothic')

plt.bar(jeju2015.index, jeju2015['개수'])
plt.show()
# Out:
# C:\Users\gesta\AppData\Local\Temp\ipykernel_24392\1782710092.py:1: FutureWarning: The default value of numeric_only in DataFrameGroupBy.sum is deprecated. In a future version, numeric_only will default to False. Either specify numeric_only or select only columns which should be valid for the function.
#   jeju2015 = jeju2015.groupby('유형').sum()
